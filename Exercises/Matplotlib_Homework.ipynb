# %% [markdown]
# **Задание 1**
#
# Загрузите модуль pyplot библиотеки matplotlib с псевдонимом plt, а также библиотеку numpy с псевдонимом np.
# Примените магическую функцию %matplotlib inline для отображения графиков в Jupyter Notebook и настройки конфигурации ноутбука со значением 'svg' для более четкого отображения графиков.
# Создайте список под названием x с числами 1, 2, 3, 4, 5, 6, 7 и список y с числами 3.5, 3.8, 4.2, 4.5, 5, 5.5, 7.
# С помощью функции plot постройте график, соединяющий линиями точки с горизонтальными координатами из списка x и вертикальными - из списка y.
# Затем в следующей ячейке постройте диаграмму рассеяния (другие названия - диаграмма разброса, scatter plot).

# %%
from matplotlib import pyplot as plt
import numpy as np
from pylab import rcParams

rcParams["figure.figsize"] = 9, 6
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

title_dict = {'fontsize':17, 'color': 'black', 'family': 'Calibri'}
label_dict = {'fontsize':10, 'color': 'black', 'family': 'Calibri'}

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %%
plt.figure(figsize = (9, 6))
plt.plot(x, y, marker = 'o')
plt.show()

# %%
plt.figure(figsize = (9, 6))
plt.scatter(x, y)
plt.show()

# %% [markdown]
# **Задание 2**
#
# С помощью функции linspace из библиотеки Numpy создайте массив t из 51 числа от 0 до 10 включительно.
# Создайте массив Numpy под названием f, содержащий косинусы элементов массива t.
# Постройте линейную диаграмму, используя массив t для координат по горизонтали,а массив f - для координат по вертикали. Линия графика должна быть зеленого цвета.
# Выведите название диаграммы - 'График f(t)'. Также добавьте названия для горизонтальной оси - 'Значения t' и для вертикальной - 'Значения f'.
# Ограничьте график по оси x значениями 0.5 и 9.5, а по оси y - значениями -2.5 и 2.5.

# %%
t = np.linspace(0, 10, 51)
f = np.cos(t)

plt.figure(figsize = (9, 6))
plt.plot(t, f, color = 'Green')
plt.title('График f(t)', fontdict=title_dict)
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.show()

# %% [markdown]
# ***Задание 3**
#
#
# С помощью функции linspace библиотеки Numpy создайте массив x из 51 числа от -3 до 3 включительно.
# Создайте массивы y1, y2, y3, y4 по следующим формулам:
# y1 = x**2
# y2 = 2 * x + 0.5
# y3 = -3 * x - 1.5
# y4 = sin(x)
# Используя функцию subplots модуля matplotlib.pyplot, создайте объект matplotlib.figure.Figure с названием fig и массив объектов Axes под названием ax,причем так, чтобы у вас было 4 отдельных графика в сетке, состоящей из двух строк и двух столбцов. В каждом графике массив x используется для координат по горизонтали.В левом верхнем графике для координат по вертикали используйте y1,в правом верхнем - y2, в левом нижнем - y3, в правом нижнем - y4.Дайте название графикам: 'График y1', 'График y2' и т.д.
# Для графика в левом верхнем углу установите границы по оси x от -5 до 5.
# Установите размеры фигуры 8 дюймов по горизонтали и 6 дюймов по вертикали.
# Вертикальные и горизонтальные зазоры между графиками должны составлять 0.3.

# %%
x = np.linspace(-3, 3, 51)

y1 = x**2
y2 = 2*x + 0.5
y3 = -3*x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2)
ax1, ax2, ax3, ax4 = ax.flatten()

ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
ax4.plot(x, y4)

ax1.set_title('График y1', fontdict=title_dict)
ax2.set_title('График y2', fontdict=title_dict)
ax3.set_title('График y3', fontdict=title_dict)
ax4.set_title('График y4', fontdict=title_dict)

ax1.set_xlim([-5, 5])

fig.set_size_inches(9,6)
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

# %% [markdown]
# ***Задание 4**
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud
#
# Данный датасет является примером несбалансированных данных, так как мошеннические операции с картами встречаются реже обычных.
# Импортруйте библиотеку Pandas, а также используйте для графиков стиль “fivethirtyeight”.
# Посчитайте с помощью метода value_counts количество наблюдений для каждого значения целевой переменной Class и примените к полученным данным метод plot, чтобы построить столбчатую диаграмму. Затем постройте такую же диаграмму, используя логарифмический масштаб.
# На следующем графике постройте две гистограммы по значениям признака V1 - одну для мошеннических транзакций (Class равен 1) и другую - для обычных (Class равен 0). Подберите значение аргумента density так, чтобы по вертикали графика было расположено не число наблюдений, а плотность распределения. Число бинов должно равняться 20 для обеих гистограмм, а коэффициент alpha сделайте равным 0.5, чтобы гистограммы были полупрозрачными и не загораживали друг друга. Создайте легенду с двумя значениями: “Class 0” и “Class 1”. Гистограмма обычных транзакций должна быть серого цвета, а мошеннических - красного. Горизонтальной оси дайте название “Class”.

# %%
import pandas as pd

plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('../Dataframes/creditcard.csv', sep = ',')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
plt.figure(figsize = (9, 6))
df['Class'].value_counts().plot(kind = 'bar', logy = True, color='Grey')
plt.title('Normal and Fraud transactions', fontdict=title_dict)
plt.show()

# %%
df_fraud = df.loc[df['Class'] == 1, ['V1']]
df_normal = df.loc[df['Class'] == 0, ['V1']]

plt.figure(figsize = (9, 6))
plt.hist(df_normal, bins = 20, ec = 'White', color = 'Blue', alpha=0.5, density=True, label = 'Normal')
plt.hist(df_fraud, bins = 20, ec = 'White', color = 'Orange', alpha=0.5, density=True, label = 'Fraud')
plt.title('Card transactions distribution', fontdict=title_dict)
plt.legend()

plt.show()

# %% [markdown]
# ***Задание 5**
#
# В этом задании продолжаем работать с датасетом [Netflix Movies and TV Shows](https://www.kaggle.com/shivamb/netflix-shows) . Ознакомьтесь с описанием данных и скачайте датасет netflix_titles.csv с сайта Kaggle.com
# 1. Загрузите датасет и постройте столбчатую диаграмму с количеством фильмом/сериалов на протяжении с 2010 по 2016. По оси x - год выпуска, по y - количество фильмом/сериалов.

# %%
df = pd.read_csv('../Dataframes/netflix_titles.csv', sep = ',')

# %%
df.sample(2)
# Out:
#      show_id     type                              title director  \
# 1214   s1215  TV Show  Care Bears: Welcome to Care-a-Lot      NaN
# 1748   s1749    Movie            Diana: In Her Own Words      NaN
#
#                                                    cast         country  \
# 1214  David Lodge, Patty Mattson, Doug Erholtz, Step...   United States
# 1748                                                NaN  United Kingdom
#
#             date_added  release_year rating  duration  \
# 1214    August 2, 2019          2012   TV-Y  1 Season
# 1748  December 1, 2017          2017  TV-PG   113 min
#
#                                 listed_in  \
# 1214                             Kids' TV
# 1748  Documentaries, International Movies
#
#                                             description
# 1214  Nestled in a faraway cloud is a rainbow-colore...
# 1748  Featuring archival footage and personal record...

# %%
count_films = df[['type','release_year']].loc[(df['release_year'].between(2010, 2016))]
count_by_type_year = pd.pivot_table(data=count_films,
                                    columns='type',
                                    index='release_year',
                                    aggfunc=np.ma.count)
count_by_type_year
# Out:
# type          Movie  TV Show
# release_year
# 2010            272       74
# 2011            254       78
# 2012            316      122
# 2013            404      130
# 2014            488      180
# 2015            764      318
# 2016           1284      480

# %%
years = count_by_type_year.index
movie = count_by_type_year['Movie'] 
tv_show = count_by_type_year['TV Show'] 
width = 0.3
x = np.arange(len(years))
fig, ax = plt.subplots()
fig.set_size_inches(9,6)
pl1 = ax.bar(x - width/2, movie, width, label='movies', color='#01c5c4')
pl2 = ax.bar(x + width/2, tv_show, width, label='TV shows', color='#ff7a05')
ax.set_title('Total movies and TV shows in period 2010-2016', fontdict=title_dict)
ax.set_xticks(x)
plt.tick_params(axis='both', which='major', labelsize=10)
ax.set_xticklabels(years, fontsize=14)
plt.xlabel("Year", fontdict=title_dict)
plt.ylabel("Total", fontdict=title_dict)
ax.legend(frameon=False)

plt.show()

# %% [markdown]
# 2. Постройте один график, показывающий как много фильмов и сериалов выпускались на всем промежутке времени. По оси x - год выпуска, по y - количество фильмов и сериалов.

# %%
count_films = df[['type','release_year']]
count_by_type = pd.pivot_table(data=count_films,
                               columns='type',
                               index='release_year',aggfunc=np.ma.count, 
                               fill_value=0)
count_by_type
# Out:
# type          Movie  TV Show
# release_year
# 1925              0        2
# 1942              4        0
# 1943              6        0
# 1944              6        0
# 1945              6        0
# ...             ...      ...
# 2017           1488      536
# 2018           1468      774
# 2019           1164      828
# 2020            822      914
# 2021             24       38
#
# [73 rows x 2 columns]

# %%
plt.figure(figsize = (9, 6))

plt.plot(count_by_type['Movie'], label='Movies', color='#01c5c4', linewidth = 2.5)
plt.plot(count_by_type['TV Show'], label='TV Shows', color='#ff7a05', linewidth = 2.5)
plt.xlabel('Year')
plt.ylabel('Total')
plt.title('Total movies and TV shows by years')
plt.tick_params(axis='both', which='major', labelsize=10)
plt.legend(frameon=False)
fig.set_facecolor('floralwhite')
plt.show()

# %% [markdown]
# 3. Постройте столбчатую диаграмму, на которой отобразите количество сериалов, представленных в данных, по сезонам (ограничьтесь 10 самыми популярными количествами сезонов). По оси x - количество сезонов, по y - количество сериалов. Сделайте так, чтобы количество сезонов по оси ординат не накладывались друг на друга.

# %%
tv_shows = df[df['type'] == 'TV Show'].duration.value_counts()[:10]
tv_shows
# Out:
# 1 Season      1608
# 2 Seasons      382
# 3 Seasons      184
# 4 Seasons       87
# 5 Seasons       58
# 6 Seasons       30
# 7 Seasons       19
# 8 Seasons       18
# 9 Seasons        8
# 10 Seasons       6
# Name: duration, dtype: int64

# %%
plt.figure(figsize = (9, 6))

tv_shows.plot(kind='bar', label='TV Shows', color='#fe7171')
plt.xlabel('Duration')
plt.ylabel('Total')
plt.title('Distribution of TV shows by duration')
plt.tick_params(axis='both', which='major', labelsize=10)
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# 4. Постройте pie диаграмму, показывающую соотношение количества сериалов к фильмам. Отобразите процентное соотношение на графике и название частей.

# %%
count_by_type.sum()
# Out:
# type
# Movie      10754
# TV Show     4820
# dtype: int64

# %%
total = count_by_type.sum()
type = count_by_type.sum().index

fig, ax = plt.subplots()
fig.set_size_inches(9,6)
ax.pie(total, labels=type, autopct='%1.1f%%', shadow=True, colors=['#6D597A', '#fe7171'])
ax.axis("equal")
plt.title('Movies and TV shows percentage')
# Out:
# Text(0.5, 1.0, 'Movies and TV shows percentage')
